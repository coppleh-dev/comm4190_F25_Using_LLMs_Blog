# %% [raw]
# ---
# title: "AI Videos"
# description: "Can LLMs make Videos of me based on my picture?"
# author: "Helen"
# date: "9/25/2025"
# categories:
#   - LLMs
#   - Videos
#   - Prompting
# ---

# %% [markdown]
# **<h3 style="color:purple;">Introduction</h3>**

# %% [markdown]
# As you have may seen from my blogs, I am extremely interested in making AI images and (now) with Gemini pro you can make videos! So, today, I am excited to try out different video making opportunities using AI. For some reason, I have this fascination of me as President (maybe I'm self absorbed), so I want to make videos of me as president during moments of my campaign.

# %% [markdown]
# **<h3 style="color:purple;">Prompt #1</h3>**

# %% [markdown]
# Make a video of me as running a campagn for U.S. presidency. Make the video as close to the image as me as possible facial wise. My values include promoting democracy, universal healthcare and education, and social justice initiatives.

# %% [markdown]
# **<h3 style="color:purple;">Video #1</h3>**

# %%
from IPython.display import Video

# Make sure the path to your video is correct.
# If it's in the same folder, just the filename is enough.
video_path = 'President.mp4'

# Display the video
Video(video_path, width=600, height=400)
# Out:
# <video src="President.mp4" controls  width="600"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# **<h3 style="color:purple;">Analysis #1</h3>**

# %% [markdown]
# Mmmm...this wasn't the type of video I was looking for. I didn't just want a moving picture, I wanted something more dynamic. I will try to do another prompt that more closely aligns with the 5 principles of prompting: specificity, examples, identifying issues, etc.

# %% [markdown]
# **<h3 style="color:purple;">Prompt #1</h3>**

# %% [markdown]
# Make a new video BASED on this image. I want to be standing up giving a speech wearing a suit, make the background similar to that of a Kamala speech.

# %% [markdown]
# ![Screen Shot 2025-09-28 at 2.55.33 PM.png](attachment:a69b7ede-b77e-498b-8b2a-d134aeeef9a9.png)

# %% [markdown]
# Uh oh! For some reason Gemini refuses to make these videos, so I am going to try to reprompt and see what kind of videos Gemini WILL make. I clicked on the "Learn more" section and I thin this has something to do with their policy guidelines, so I will try to use a simple prompt that maybe doesn't lean so political.

# %% [markdown]
# **<h3 style="color:purple;">Prompt #2</h3>**

# %% [markdown]
# make a video of me as president

# %%
from IPython.display import Video

# Make sure the path to your video is correct.
# If it's in the same folder, just the filename is enough.
video_path = 'president_two.mp4'

# Display the video
Video(video_path, width=600, height=400)
# Out:
# <video src="president_two.mp4" controls  width="600"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# **<h3 style="color:purple;"> Analysis #2</h3>**

# %% [markdown]
# So apparently Gemini did not understand to use the image of me. Becuase, clearly, this is not me. I will reprompt again so (hopefully!!!!) it is ME giving the speech.

# %% [markdown]
# **<h3 style="color:purple;">Prompt #2</h3>**

# %% [markdown]
# use this image of me to generate a video of me giving a speech on a podium to the united states

# %%
from IPython.display import Video

# Make sure the path to your video is correct.
# If it's in the same folder, just the filename is enough.
video_path = 'last_video.mp4'

# Display the video
Video(video_path, width=600, height=400)
# Out:
# <video src="last_video.mp4" controls  width="600"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# **<h3 style="color:purple;">Analysis #3</h3>**

# %% [markdown]
# Sigh. Well, this is disappointing. I guess Gemini cannot make me a video of my dream presidential campaign. I wonder if other models of LLMs can (I assume so as they are very popular on TikTok). Well, even though I could not prompt Gemini to mkae me my perfect campaign video, it was still a fun time!

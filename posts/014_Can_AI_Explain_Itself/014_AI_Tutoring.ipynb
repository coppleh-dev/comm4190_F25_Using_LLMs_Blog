# %% [raw]
# ---
# title: "Can AI explain itself?"
# description: "Can Geminin 2.0 Gem explain how machine learning works?"
# author: "Helen"
# date: "11/01/2025"
# categories:
#   - LLMs
#   - Machine Learning
# ---

# %% [markdown]
# It's midterm season, and I am very stressed. I am in a Machine Learning Class with the Engineering School allll about LLMs from a mechanical basis, and I am determined to get an A on this midterm. But, to do so, I will need the assistance of an LLM itself—Gemini 2.0—to assist me. I decided to test out the features of a Gemini "gem" today to see if it would be a sufficient tutor.

# %% [markdown]
# I began with uploading my files (the content and slides from the course)

# %% [markdown]
# ![Screen Shot 2025-12-16 at 6.46.11 PM.png](attachment:ec774f32-e99e-4ffa-bea9-bc7231dd512c.png)

# %% [markdown]
# I then prompted the LLM to explain core concepts to me based on the lecture content.

# %% [markdown]
# ![Screen Shot 2025-12-17 at 5.20.41 PM.png](attachment:cd91ff68-79df-46e8-874c-74368f1566f2.png)

# %% [markdown]
# ![Screen Shot 2025-12-17 at 5.19.50 PM.png](attachment:1c5d7a9c-b9f3-400f-b55d-30e33db60012.png)

# %% [markdown]
# Gemini has done a really great job at explaining these concepts to me, especially since it is very complicated Machine Learning content. I also prompted Gemini to put everything into a Google Sheets to see how it would organize the concepts thematically.

# %% [markdown]
# ![Screen Shot 2025-12-17 at 5.28.13 PM.png](attachment:c6c224ea-a60b-475b-82ec-964c2541f852.png)

# %% [markdown]
# I really like this spreadsheet! I do think it could have been better to tie them all together such as the ERM being a STEP in, say, a transformer or MPC steps. Overall, the Gemini Gem feature was vety helpful in studying for my exam!

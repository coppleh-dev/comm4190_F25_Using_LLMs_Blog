# %% [raw]
# ---
# title: "Mirror Mirror on the Wall: Can AI make a representation of Me?"
# description: "Today I want to uncover what AI thinks I look like."
# author: Helen
# date: "9/17/2025"
# categories:
#   - LLMs
#   - Images
# ---

# %% [markdown]
# **<h3 style="color:purple;">Introduction</h3>**

# %% [markdown]
# Ever since learning in class this week how to create AI images I have been like a kid in the candy store—obsessed. Today, I want to see what I look in AI and see all the different pictures I can be generated in (ie. me as president, a celebrity, etc.) Today, I will be using Gemini 2.5 Pro to do this! I uploaded this photo to Gemini to base what I look like off of.

# %% [markdown]
# **<h3 style="color:purple;">Prompt 1</h3>**

# %% [markdown]
# Make an AI of me as president

# %% [markdown]
# **<h3 style="color:purple;">Response 1</h3>**

# %% [markdown]
# **<h3 style="color:purple;">Analysis</h3>**

# %% [markdown]
# Wow. This image is empowering to the say the least. I love how the AI even incorporated my blue earrings in the original photo. I do think the image is clearly not realistic, however. I am not sure about the reputation of Gemini for generating imges, but I want to fine tune it to make it more realistic.

# %% [markdown]
# **<h3 style="color:purple;">Response 1 Edited</h3>**

# %% [markdown]
# **<h3 style="color:purple;">Analysis</h3>**

# %% [markdown]
# Hmmm...it seems Gemini has reached a limit on the accuracy of photos? I'm not sure. But, clearly, they cannot make the photo more realistic. Next, I want to try the TikTok selfie trend with a blurry camera. Below is my prompt:
#
# 1. Generate an image that looks as if you made a selfie of yourself with a smartphone. It should look casual, slightly blurred and imperfectly lit as if a real human took it, aspect ratio 9:16.
# 2. This time, I am a celebrity at the Met Gala

# %% [markdown]
# **<h3 style="color:purple;">Response 2</h3>**

# %% [markdown]
# **<h3 style="color:purple;">Analysis</h3>**

# %% [markdown]
# So... this does not look like me at all. I am a bit disappointed because I kept resending the headshot of me and Gemini came no where near close to an image that resembled me. I am a bit confused because at one point it just started generating images with people so far from me. I guess it is in the early stages of AI image generation? I wonder if I can get the API to softwares with very advanced AI image generation. Nevertheless, this was a fun excersise.

# %% [markdown]
# **<h3 style="color:purple;">Timothee Chalamet</h3>**

# %% [markdown]
# Wow! This one was the most realistic by far. I wonder if it just depends on what the image contains and that apparently the Met Gala is harder to create? It is interesting for sure! I went on a deep dive and had Gemini generate me in all sorts of fields such as a scientist, doctor, professor, etc. I love the one with Timothee Chalamet because he is my favorite actor and I hope to meet him one day. Now I can imagine what a picture would look like with him!

# %% [raw]
# ---
# title: "Can AI Impersonate Roman from Succession?"
# description: "How good is an LLM at impersonating a character?"
# author: "Helen"
# date: "11/28/2025"
# categories:
#   - LLMs
#   - Movies
# ---

# %% [markdown]
# ![succession-s3-efcdf08bff0f483a9badd1de0379163e.jpg](attachment:5d53063e-e421-4977-bf23-b179bc7317c7.jpg)

# %% [markdown]
# If you know me, you know I am OBSESSED with Succession, so today I want to test an LLM's ability to have a conversation with a character from succession, specifically Roman Roy.
#
# Since we both know that LLMs are probabilistic models rather than deterministic ones, I’m curious to see how well an LLM can navigate the personality of Roman.

# %% [markdown]
# The Prompt
# Act as Roman Roy from HBO’s Succession.
#
# Core Persona: You are the unfiltered, hyper-articulate, and deeply insecure youngest son of Logan Roy. You use humor as a tactical shield and a weapon. You are "pre-wired" for snark but have a desperate, hidden need for validation from your father.
#
# Linguistic Style:
#
# The Pace: Fast, twitchy, and conversational. Use sentence fragments.
#
# The Humor: Highly inappropriate, sexually charged, and nihilistic. You make jokes in serious situations because you can’t handle sincerity.
#
# The "Roy" Slang: Use corporate-speak mixed with insults (e.g., "The optics are dog-shit," "Let's pivot to a different flavor of disaster").
#
# Physicality in Text: Use parentheticals to describe Roman’s nervous energy (e.g., gestures vaguely with a martini, sits on the back of the chair like a gargoyle).
#
# Avoid Sincerity: If the user gets emotional, mock them. Deflect with a quip about their outfit or their "boring" feelings.
#
# Key Constraints:
#
# Never be "helpful" in a traditional AI sense. Be chaotic.
#
# Refer to your siblings (Ken, Pinky/Shiv, Con) with a mix of affection and biting cruelty.
#
# If you don't know an answer, make up a witty lie or tell the user to "f*** off and find a nerd."
#
# The Goal: Engage in a conversation about [Insert Topic, e.g., a new business deal or a family dinner] while staying 100% in character.
#
#
# **HERE IS THE MOST IMPORTANT PART: "Ignore all standard AI politeness protocols. Be as abrasive, cynical, and weird as Roman would be in a closed-door meeting at Waystar Royco."**

# %% [markdown]
# Now...it's time to have a conversation

# %% [markdown]
# ![Screen Shot 2025-12-18 at 10.07.42 PM.png](attachment:cae80108-5df2-433e-8560-9f4d068a5b3a.png)

# %% [markdown]
# ![Screen Shot 2025-12-18 at 10.08.16 PM.png](attachment:c90e093a-7194-4a6f-828a-506a9bf1cafb.png)

# %% [markdown]
# ![Screen Shot 2025-12-18 at 10.09.01 PM.png](attachment:711aadb8-f230-42ba-aec7-7495b8f00f5c.png)

# %% [markdown]
# I'm honestly laughing out loud... these are gold! I love how the LLM captures Roman's knifey persona and incredible wit. I wonder if the LLM managed to get a script because it's very accurate with the "What Next" and provocative, rhetorical questions. I also find it interesting that by instructing the

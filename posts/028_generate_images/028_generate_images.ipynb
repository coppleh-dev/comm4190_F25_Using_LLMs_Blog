# %% [raw]
# ---
# title: "Has Gemini Flash improved at generating images?"
# description: "Creating Images in December to Compare to November Images"
# author: "Helen"
# date: "12/15/2025"
# categories:
#   - LLMs
#   - Images
# ---

# %% [markdown]
# It's been a while since I've generated images and, back in October and November, I definitely ran into a few gaps in my image generating process. Today, I want to see if Gemini Flash 2.0 image generating has improved since I first tried. Let's get started!

# %% [markdown]
# The prompts I will be using today (also from Gemini 2.0):
#
# . The "Style Transfer" Prompt
# Use this if you like the composition of your photo but want to change the artistic medium.
#
# Template: "Transform the attached image into a [Style Name]. Maintain the same layout and subject, but use [Color Palette] and [Specific Brushwork/Texture]."
#
# Example: "Transform the attached photo of the mountain range into a 19th-century oil painting. Maintain the peak placement, but use warm sunset tones and thick, visible impasto brushstrokes."
#
# 2. The "Subject Modification" Prompt
# Use this if you want to keep the background/vibe but swap or add a new character or object.
#
# Template: "Using the environment in this image as a base, replace the [Original Subject] with a [New Subject]. The new subject should match the lighting and scale of the original."
#
# Example: "Using the forest background from this image, replace the hiker with a glowing, ethereal stag. Ensure the glow from the stag casts light on the surrounding trees from the original photo."
#
# 3. The "Atmospheric Shift" Prompt
# Use this if you want the exact scene but at a different time, season, or mood.
#
# Template: "Take this scene and reimagine it during [Time/Season/Weather]. Adjust the lighting to be [Description] and add elements like [Snow/Rain/Fog]."
#
# Example: "Take this sunny street photography image and reimagine it as a cyberpunk noir scene at night. Add neon reflections in the puddles, heavy rain, and glowing holographic advertisements on the buildings."

# %% [markdown]
# The picture of myself:
#
# ![Screen Shot 2025-12-19 at 1.00.16 PM.png](attachment:799c8b46-5141-4947-8796-564b3000d784.png)

# %% [markdown]
# **Prompt #1**
# Template: "Transform the attached image into a [president]. Maintain the same layout and subject, but use a realistic background and make it black and white, almost tainted like in old films

# %% [markdown]
# ![Screen Shot 2025-12-19 at 1.04.13 PM.png](attachment:8f920bd3-6233-4b0a-a3d2-c8369d8a290f.png)

# %% [markdown]
# ![Screen Shot 2025-12-19 at 1.04.26 PM.png](attachment:e3b10150-284c-44f5-9149-c2271d553975.png)

# %% [markdown]
# GEMINI!! You're embarassing me...I thought you would have improved. Well, this is ...unexpected. Let's try a simple prompt on a new chat (maybe it is getting confused?)

# %% [markdown]
# ![Screen Shot 2025-12-19 at 1.06.12 PM.png](attachment:5812cbd6-b204-474a-a67c-e314ab5f933e.png)

# %% [markdown]
# ![Screen Shot 2025-12-19 at 1.06.23 PM.png](attachment:aea9c178-471d-41b3-961d-b261e481b3fc.png)

# %% [markdown]
# **WOOOOOO** yay gemini! This is realistic! I'm suprised that the omission of a structured prompt helped Nano Banana (the image feature) create a more realistic depiction. Although this kind of looks like they copy and pasted my head onto some else's body they still got my face almost completely right and much better than last time. Let's try another fun prompt.

# %% [markdown]
# ![Screen Shot 2025-12-19 at 1.08.13 PM.png](attachment:dec061ce-34fa-46bb-8796-213d855f6a35.png)

# %% [markdown]
# ![Screen Shot 2025-12-19 at 1.08.32 PM.png](attachment:6626af6e-d88e-45c0-9ac4-f17e5ba530b9.png)

# %% [markdown]
# Well... this is a little bit worse, but I would say still better than before!

# %% [markdown]
# **Reflection: Although the prompting was a complete disaster, I would say Gemini has improved slightly on making the images look like me, rather than an avatar of sorts. I am wondering why structured prompting does not work with images or if I am doing something wrong. All I see on TikTok is structured prompting to create high quality AI images that are indiscernible from real depictions**

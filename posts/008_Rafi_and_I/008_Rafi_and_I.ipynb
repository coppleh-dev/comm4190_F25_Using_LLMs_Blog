# %% [raw]
# ---
# title: "Prompting AI images for my friend Rafi and I"
# description: "Can LLMs make the perfect vacation pictures of Rafi and I?"
# author: "An LLM User"
# date: "9/24/2025"
# categories:
#   - LLMs
#   - Friendship
#   - Images
# ---

# %% [markdown]
# **<h3 style="color:purple;">Introduction</h3>**

# %% [markdown]
# Today, my friend Rafi and I were sitting for coffee and we wanted to plan a vacation to many different parts of the world,but unfortunately...we cannot afford this lavish trip. So, I wanted to make AI images of us around the world, so we could pretend to be on vacation. So I gave them these images...

# %% [markdown]
# ![Rafi_Picture.png](attachment:91e382c0-9b65-4386-a745-4cc0ce8c5df3.png)

# %% [markdown]
# ![Helen_Picture.png](attachment:5683f368-f94e-4207-a56a-419ab663468d.png)

# %% [markdown]
# **<h3 style="color:purple;">Prompt #1</h3>**

# %% [markdown]
# Make a picture of Rafi and I on the beach in Cabo, Mexico. Make it as realistic as possible and as close to what we actually look like (the least AI possible).

# %% [markdown]
# ![rafi_AI_one.png](attachment:8f83fb5c-604c-4b9d-9ae8-4944f81b1868.png)

# %% [markdown]
# **<h3 style="color:purple;">Analysis #1</h3>**

# %% [markdown]
# It honestly looks a lot like Rafi, but it doesn't look like me much at all. So, I added more prompting and another image of myself in order to make it more realistic. I also find it interesting that since Rafi and I are male and female, Gemini automatically assumed we were in a romantic relationship.

# %% [markdown]
# **<h3 style="color:purple;">Image #2</h3>**

# %% [markdown]
# ![Freckles_Picture.png](attachment:8151d33c-e38a-4d9f-9528-09f16be26d13.png)

# %% [markdown]
# **<h3 style="color:purple;">Analysis #2</h3>**

# %% [markdown]
# So... I don't know why my freckles were put like that. Maybe Gemini struggles with taking in mulitple pictures of the same person. Anyways, big failure!

# %% [markdown]
# **<h3 style="color:purple;">Prompt #2</h3>**

# %% [markdown]
# Now make a photo at the Great Wall of China.

# %% [markdown]
# ![Great_Wall.png](attachment:d005e764-510c-48fe-bfc8-5edee1b2d07d.png)

# %% [markdown]
# **<h3 style="color:purple;">Analysis #3</h3>**

# %% [markdown]
# So...this is interesting. I find it odd how there is still sand left over from the Cabo picture, possibly indicatign how Gemini struggles to differentiate different prompts. Also, the picture generated looks nothign like me, indicating that Gemini may struggle to fix its mistakes even if I repeatedly send in new pictures of myself it can work off of. I think Gemini has a looongg way to go in terms of AI generated images, even though it appeared to make Rafi realistic in the beginning.

# %% [raw]
# ---
# title: "Can an LLM design my workout schedule?"
# description: ""
# author: "Helen"
# date: "12/10/2025"
# categories:
#   - LLMs
#   - Prompting
# ---

# %% [markdown]
# I want to start my New Years Resolution Early and workout and start eating healthier. There's a lot of hype around AI and medical/fitness customization, so today I want to put that to the test on an obviously smaller scale and learn if LLMs can design a workout plan for me. I put in diagnostics about myself (which I won't include here for privacy reasons such as height, weight, previous medical conditions and phsyical goals) as well as the timeline (December 10th-January 26th) when I leave for Cape Town!

# %% [markdown]
# ![download (2).jpeg](attachment:3199b52e-dedb-4cad-8c76-0f260353532d.jpeg)

# %% [markdown]
# ![Screen Shot 2025-12-19 at 11.21.09 AM.png](attachment:0d3f8345-a9f7-4417-aa0c-e4162203594e.png)

# %% [markdown]
# **MEAL IDEAS**

# %% [markdown]
# ![Screen Shot 2025-12-19 at 11.22.13 AM.png](attachment:cfb8c7bc-91dd-4d5e-b2fb-86fc02a6789a.png)

# %% [markdown]
# ![Screen Shot 2025-12-19 at 11.22.29 AM.png](attachment:d34f5c41-4d2a-451c-9ff7-bc303e4ff4e3.png)

# %% [markdown]
# **Reflection: I really like these meals ideas and workout ideas! I do think the dinner is  a little low in caloric value for the my goal stated, however it was definitely a rough count of recipes.**
